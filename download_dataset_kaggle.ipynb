# %% [markdown]
# # Download Fruit Dataset from Kaggle
#
# This notebook downloads `sriramr/fruits-fresh-and-rotten-for-classification` and prepares the fresh fruit folders expected by the project:
#
# - `dataset/train/freshapples/`
# - `dataset/train/freshoranges/`
# - `dataset/train/freshbananas/`
# - `dataset/test/freshapples/`
# - `dataset/test/freshoranges/`
# - `dataset/test/freshbananas/`
#
# Before running, download your Kaggle API token from `https://www.kaggle.com/settings` and save it as:
#
# ```text
# C:\Users\Rafael Po\.kaggle\kaggle.json
# ```

# %% [markdown]
# ## 1. Install Kaggle API
#
# Run this cell once. If `kaggle` is already installed, it will simply confirm the package is available.

# %%
# %pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\rafael po\fruit_grading_env\lib\site-packages (2.0.2)
# Requirement already satisfied: bleach in c:\users\rafael po\fruit_grading_env\lib\site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: jupytext in c:\users\rafael po\fruit_grading_env\lib\site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.20 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from kaggle) (0.1.20)
# Requirement already satisfied: packaging in c:\users\rafael po\fruit_grading_env\lib\site-packages (from kaggle) (26.1)
# Requirement already satisfied: protobuf in c:\users\rafael po\fruit_grading_env\lib\site-packages (from kaggle) (4.25.9)
# Requirement already satisfied: python-dateutil in c:\users\rafael po\fruit_grading_env\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\rafael po\fruit_grading_env\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in c:\users\rafael po\fruit_grading_env\lib\site-packages (from kaggle) (2.33.1)
# Requirement already satisfied: tqdm in c:\users\rafael po\fruit_grading_env\lib\site-packages (from kaggle) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from kaggle) (2.6.3)
# Requirement already satisfied: webencodings in c:\users\rafael po\fruit_grading_env\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: markdown-it-py>=1.0 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from jupytext->kaggle) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\rafael po\fruit_grading_env\lib\site-packages (from jupytext->kaggle) (0.5.0)
# Requirement already satisfied: nbformat in c:\users\rafael po\fruit_grading_env\lib\site-packages (from jupytext->kaggle) (5.10.4)
# Requirement already satisfied: pyyaml in c:\users\rafael po\fruit_grading_env\lib\site-packages (from jupytext->kaggle) (6.0.3)
# Requirement already satisfied: six>=1.5 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from requests->kaggle) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from requests->kaggle) (3.13)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from requests->kaggle) (2026.4.22)
# Requirement already satisfied: colorama in c:\users\rafael po\fruit_grading_env\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from markdown-it-py>=1.0->jupytext->kaggle) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from nbformat->jupytext->kaggle) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from nbformat->jupytext->kaggle) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from nbformat->jupytext->kaggle) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from nbformat->jupytext->kaggle) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (4.9.6)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\rafael po\fruit_grading_env\lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->jupytext->kaggle) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2. Configure Paths
#
# These paths are set for this project and your Windows username.

# %%
from pathlib import Path

DATASET_SLUG = "sriramr/fruits-fresh-and-rotten-for-classification"

USER_HOME = Path(r"C:\Users\Rafael Po")
KAGGLE_JSON = USER_HOME / ".kaggle" / "kaggle.json"

PROJECT_ROOT = Path(r"C:\Users\Rafael Po\Kuliah\Semester 6\DeepLearning\fruit-grading")
RAW_DIR = PROJECT_ROOT / "raw"
DATASET_ROOT = PROJECT_ROOT / "dataset"

print(f"Kaggle credentials: {KAGGLE_JSON}")
print(f"Raw download folder: {RAW_DIR}")
print(f"Prepared dataset folder: {DATASET_ROOT}")
# Out:
# Kaggle credentials: C:\Users\Rafael Po\.kaggle\kaggle.json
# Raw download folder: C:\Users\Rafael Po\Kuliah\Semester 6\DeepLearning\fruit-grading\raw
# Prepared dataset folder: C:\Users\Rafael Po\Kuliah\Semester 6\DeepLearning\fruit-grading\dataset

# %% [markdown]
# ## 3. Validate Kaggle Credentials

# %%
if not KAGGLE_JSON.exists():
    raise FileNotFoundError(
        "Kaggle API token not found. Download kaggle.json from "
        "https://www.kaggle.com/settings and place it at: "
        f"{KAGGLE_JSON}"
    )

RAW_DIR.mkdir(parents=True, exist_ok=True)
DATASET_ROOT.mkdir(parents=True, exist_ok=True)

print("Kaggle credentials found.")
# Out:
# Kaggle credentials found.

# %% [markdown]
# ## 4. Download and Extract Dataset
#
# This downloads the Kaggle zip into `raw/` and extracts it there.

# %%
import zipfile

from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

api.dataset_download_files(
    DATASET_SLUG,
    path=str(RAW_DIR),
    unzip=False,
)

zip_path = RAW_DIR / "fruits-fresh-and-rotten-for-classification.zip"
extract_dir = RAW_DIR / "fruits-fresh-and-rotten-for-classification"

if not zip_path.exists():
    raise FileNotFoundError(f"Expected zip file was not found: {zip_path}")

if not extract_dir.exists():
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        zip_ref.extractall(extract_dir)
    print(f"Extracted dataset to: {extract_dir}")
else:
    print(f"Dataset already extracted at: {extract_dir}")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sriramr/fruits-fresh-and-rotten-for-classification
# Extracted dataset to: C:\Users\Rafael Po\Kuliah\Semester 6\DeepLearning\fruit-grading\raw\fruits-fresh-and-rotten-for-classification

# %% [markdown]
# ## 5. Copy Fresh Fruit Folders into `dataset/`
#
# Only fresh apples, oranges, and bananas are copied. Rotten fruit folders are ignored.

# %%
import shutil

source_root = extract_dir / "dataset"
if not source_root.exists():
    source_root = extract_dir

fresh_folders = ["freshapples", "freshoranges", "freshbanana"]
splits = ["train", "test"]

for split in splits:
    for fruit_folder in fresh_folders:
        src = source_root / split / fruit_folder
        dst = DATASET_ROOT / split / fruit_folder

        if not src.exists():
            raise FileNotFoundError(f"Expected source folder was not found: {src}")

        dst.parent.mkdir(parents=True, exist_ok=True)

        if dst.exists():
            shutil.rmtree(dst)

        shutil.copytree(src, dst)

print("Fresh fruit folders copied into dataset/.")
# Out:
# Fresh fruit folders copied into dataset/.

# %% [markdown]
# ## 6. Verify Dataset Structure

# %%
image_extensions = {".jpg", ".jpeg", ".png", ".bmp", ".webp"}

print("Dataset ready:")
for split in splits:
    for fruit_folder in fresh_folders:
        folder = DATASET_ROOT / split / fruit_folder
        image_count = sum(1 for file in folder.iterdir() if file.suffix.lower() in image_extensions)
        print(f"{split}/{fruit_folder}: {image_count} images")
# Out:
# Dataset ready:
# train/freshapples: 1693 images
# train/freshoranges: 1466 images
# train/freshbanana: 1581 images
# test/freshapples: 395 images
# test/freshoranges: 388 images
# test/freshbanana: 381 images
