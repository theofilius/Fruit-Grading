# %% [markdown]
# # 🍎🍊🍌 Fruit Quality Grading
# ## Step 2: CNN Training with EfficientNetB0 (2-Phase Final)
#
# ### Key Decision: Phase 3 Removed
#
# Phase 3 (full network fine-tuning) was **removed** to prevent overfitting to K-Means label noise (~15-20%).
# **Phase 2 final model** (93% validation accuracy) is retained as the final checkpoint.
#
# ### Why No Phase 3?
#
# With noisy cluster-based labels, unfreezing all layers lets the model memorize noise rather than learn generalizable fruit quality patterns. Phase 2's partial unfreezing (top 20 layers) provides optimal domain adaptation.
#
# ### Final Pipeline (2-Phase)
# ```
# output/labeled_dataset.csv (from Step 1)
#           ↓
#   Train / Validation / Test (70/15/15)
#           ↓
#   Phase 1: Head only (frozen base, 20 epochs, LR=1e-3)
#           ↓
#   Phase 2: Top 20 layers unfrozen (25 epochs, LR=1e-5)
#           ↓
#   Evaluate & Save Model
# ```

# %% [markdown]
# ## 📦 1. Install Dependencies

# %%
# !pip install tensorflow scikit-learn pandas matplotlib seaborn opencv-python tqdm -q
print("All dependencies installed")
# Out:
# All dependencies installed
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 📚 2. Imports

# %%
import os, warnings, random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import (
    EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
)

warnings.filterwarnings("ignore")

# Reproducibility
SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

gpus = tf.config.list_physical_devices("GPU")
print(f"TensorFlow : {tf.__version__}")
print(f"GPU        : {'Yes — ' + gpus[0].name if gpus else 'No (CPU)'}")
# Out:
# TensorFlow : 2.16.1
# GPU        : No (CPU)

# %% [markdown]
# ## ⚙️ 3. Configuration
#
# Key changes from v1: lower learning rates, 3-phase training, stronger regularization.

# %%
# ---------------------------------------------
#  CONFIGURATION
# ---------------------------------------------

LABELED_CSV  = "output/labeled_dataset.csv"
OUTPUT_DIR   = "output"
MODEL_DIR    = "output/models"
RUN_VERSION  = "v4"

IMAGE_SIZE   = (224, 224)
BATCH_SIZE   = 32
RANDOM_STATE = 42

# EfficientNetB0 in tf.keras includes its own preprocessing/rescaling.
# Keep images in the native 0..255 float range for the pretrained backbone.
USE_EFFICIENTNET_NATIVE_SCALE = True

# Three-phase training (v4: recover learning capacity after v3 underfit)
# Phase 1: head only, base fully frozen
PHASE1_EPOCHS = 20
PHASE1_LR     = 1e-3

# Phase 2: unfreeze only top 20 layers of base
PHASE2_EPOCHS = 25
PHASE2_LR     = 1e-5

# Phase 3: unfreeze full network with a smaller-but-still-learning LR
PHASE3_EPOCHS = 35
PHASE3_LR     = 1e-6

# Moderate regularization
DROPOUT_1    = 0.4
DROPOUT_2    = 0.3
DENSE_L2     = 1e-4
WEIGHT_DECAY = 0.0

# Split
TRAIN_RATIO  = 0.70
VAL_RATIO    = 0.15
TEST_RATIO   = 0.15

# Classes
FRUITS      = ["apple", "orange", "banana"]
GRADES      = ["A", "B", "C"]
CLASS_NAMES = [f"{f}_{g}" for f in FRUITS for g in GRADES]

for d in [MODEL_DIR, f"{OUTPUT_DIR}/plots", f"{OUTPUT_DIR}/gradcam"]:
    Path(d).mkdir(parents=True, exist_ok=True)

print(f"Classes ({len(CLASS_NAMES)}): {CLASS_NAMES}")
print(f"Run version: {RUN_VERSION}")
print(f"EfficientNet native input scale: {USE_EFFICIENTNET_NATIVE_SCALE}")
print(f"Training phases: 3  |  Total max epochs: {PHASE1_EPOCHS+PHASE2_EPOCHS+PHASE3_EPOCHS}")
# Out:
# Classes (9): ['apple_A', 'apple_B', 'apple_C', 'orange_A', 'orange_B', 'orange_C', 'banana_A', 'banana_B', 'banana_C']
# Run version: v4
# EfficientNet native input scale: True
# Training phases: 3  |  Total max epochs: 80

# %% [markdown]
# ## 📂 4. Load & Verify Labeled Dataset

# %%
df = pd.read_csv(LABELED_CSV)
df["exists"] = df["image_path"].apply(lambda p: Path(p).exists())
missing = df[~df["exists"]]
if len(missing) > 0:
    print(f"WARNING: {len(missing)} missing paths dropped.")
    df = df[df["exists"]].copy()
df = df.reset_index(drop=True)

print(f"Total images : {len(df):,}")
print(f"\nLabel distribution:")
for label, count in df["label"].value_counts().sort_index().items():
    bar = chr(9608) * (count // 30)
    print(f"  {label:12s}  {count:>5,}  {bar}")
# Out:
# Total images : 5,904
#
# Label distribution:
#   apple_A         730  ████████████████████████
#   apple_B         671  ██████████████████████
#   apple_C         687  ██████████████████████
#   banana_A        558  ██████████████████
#   banana_B      1,095  ████████████████████████████████████
#   banana_C        309  ██████████
#   orange_A        558  ██████████████████
#   orange_B      1,173  ███████████████████████████████████████
#   orange_C        123  ████

# %% [markdown]
# ## ✂️ 5. Stratified Train / Val / Test Split

# %%
df_train, df_temp = train_test_split(
    df, test_size=(VAL_RATIO + TEST_RATIO),
    stratify=df["label"], random_state=RANDOM_STATE
)
val_frac = VAL_RATIO / (VAL_RATIO + TEST_RATIO)
df_val, df_test = train_test_split(
    df_temp, test_size=(1 - val_frac),
    stratify=df_temp["label"], random_state=RANDOM_STATE
)
df_train = df_train.reset_index(drop=True)
df_val   = df_val.reset_index(drop=True)
df_test  = df_test.reset_index(drop=True)

print(f"Train : {len(df_train):,}  ({len(df_train)/len(df)*100:.0f}%)")
print(f"Val   : {len(df_val):,}  ({len(df_val)/len(df)*100:.0f}%)")
print(f"Test  : {len(df_test):,}  ({len(df_test)/len(df)*100:.0f}%)")
# Out:
# Train : 4,132  (70%)
# Val   : 886  (15%)
# Test  : 886  (15%)

# %% [markdown]
# ## ⚖️ 6. Class Weights
#
# Since K-Means may produce unequal cluster sizes, we compute class weights so the model doesn't bias toward majority grades.

# %%
le = LabelEncoder()
le.fit(CLASS_NAMES)
NUM_CLASSES = len(le.classes_)

y_train = le.transform(df_train["label"].values)
y_val   = le.transform(df_val["label"].values)
y_test  = le.transform(df_test["label"].values)

class_weights_array = compute_class_weight(
    class_weight="balanced",
    classes=np.arange(NUM_CLASSES),
    y=y_train
)
class_weight_dict = dict(enumerate(class_weights_array))

print("Class weights (higher = minority class gets more attention):")
for idx, weight in class_weight_dict.items():
    label = le.inverse_transform([idx])[0]
    bar   = chr(9608) * int(weight * 10)
    print(f"  {label:12s}  {weight:.3f}  {bar}")
# Out:
# Class weights (higher = minority class gets more attention):
#   apple_A       0.898  ████████
#   apple_B       0.977  █████████
#   apple_C       0.954  █████████
#   banana_A      1.177  ███████████
#   banana_B      0.599  █████
#   banana_C      2.126  █████████████████████
#   orange_A      1.174  ███████████
#   orange_B      0.559  █████
#   orange_C      5.339  █████████████████████████████████████████████████████

# %% [markdown]
# ## 🔄 7. Data Pipeline & Augmentation
#
# **Stronger augmentation than v1** — essential for a small dataset (~500 images/class).

# %%
def load_and_preprocess(path, augment=False):
    """Load, resize, and optionally augment an image."""
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMAGE_SIZE)
    img = img.astype(np.float32)

    if not USE_EFFICIENTNET_NATIVE_SCALE:
        img = img / 255.0

    max_value = 255.0 if USE_EFFICIENTNET_NATIVE_SCALE else 1.0

    if augment:
        # Horizontal flip
        if np.random.rand() > 0.5:
            img = np.fliplr(img)
        # Moderate brightness jitter
        img = np.clip(img * np.random.uniform(0.8, 1.2), 0, max_value)
        # Moderate contrast jitter
        mean = img.mean()
        img = np.clip((img - mean) * np.random.uniform(0.85, 1.15) + mean, 0, max_value)
        # Moderate rotation
        angle = np.random.uniform(-15, 15)
        h, w = img.shape[:2]
        M = cv2.getRotationMatrix2D((w / 2, h / 2), angle, 1.0)
        img = cv2.warpAffine(img, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
        # Occasional random zoom: crop and resize back
        if np.random.rand() > 0.5:
            zoom = np.random.uniform(0.9, 1.0)
            ch, cw = int(h * zoom), int(w * zoom)
            y1 = np.random.randint(0, h - ch + 1)
            x1 = np.random.randint(0, w - cw + 1)
            img = img[y1:y1 + ch, x1:x1 + cw]
            img = cv2.resize(img, IMAGE_SIZE)

    return img.astype(np.float32)


def make_dataset(df_split, labels, augment=False, shuffle=False):
    """Build a tf.data.Dataset from a DataFrame."""
    paths = df_split["image_path"].values
    y_onehot = tf.keras.utils.to_categorical(labels, NUM_CLASSES)

    def generator():
        indices = np.arange(len(paths))
        if shuffle:
            np.random.shuffle(indices)
        for i in indices:
            img = load_and_preprocess(paths[i], augment=augment)
            yield img, y_onehot[i]

    ds = tf.data.Dataset.from_generator(
        generator,
        output_signature=(
            tf.TensorSpec(shape=(*IMAGE_SIZE, 3), dtype=tf.float32),
            tf.TensorSpec(shape=(NUM_CLASSES,), dtype=tf.float32),
        )
    )
    return ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)


train_ds = make_dataset(df_train, y_train, augment=True, shuffle=True)
val_ds = make_dataset(df_val, y_val, augment=False, shuffle=False)
test_ds = make_dataset(df_test, y_test, augment=False, shuffle=False)

print("Datasets ready:")
print(f"  train_ds : {len(df_train):,} images | moderate augmentation ON")
print(f"  val_ds   : {len(df_val):,} images  | augmentation OFF")
print(f"  test_ds  : {len(df_test):,} images  | augmentation OFF")
# Out:
# Datasets ready:
#   train_ds : 4,132 images | moderate augmentation ON
#   val_ds   : 886 images  | augmentation OFF
#   test_ds  : 886 images  | augmentation OFF

# %% [markdown]
# ## 🖼️ 8. Augmentation Preview

# %%
# Show one image with 8 augmented versions
sample_path = df_train.sample(1, random_state=7)["image_path"].values[0]
original    = load_and_preprocess(sample_path, augment=False)

fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes[0, 0].imshow(original)
axes[0, 0].set_title("Original", fontsize=10, fontweight="bold")
axes[0, 0].axis("off")

for i, ax in enumerate(axes.flat[1:]):
    aug = load_and_preprocess(sample_path, augment=True)
    ax.imshow(aug)
    ax.set_title(f"Augmented {i+1}", fontsize=9)
    ax.axis("off")

plt.suptitle("Augmentation Examples", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/plots/augmentation_preview.png", dpi=120, bbox_inches="tight")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [14.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [5.2071285..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.6173186..217.14124].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.33154127..213.51].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [32.693695..249.87392].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [32.25723..247.60875].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [5.27778..217.66333].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [1.1360642..215.48177].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..213.85208].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [25.399399..251.33904].

# %% [markdown]
# ## 🧠 9. Build Model — EfficientNetB0
#
# **Key fix from v1**: Higher dropout (0.5) and L2 regularization added to the dense layer.

# %%
def make_optimizer(learning_rate, weight_decay):
    """Create AdamW only when weight decay is enabled; otherwise use Adam."""
    if weight_decay and weight_decay > 0:
        if hasattr(keras.optimizers, "AdamW"):
            return keras.optimizers.AdamW(
                learning_rate=learning_rate,
                weight_decay=weight_decay,
            )
        if hasattr(keras.optimizers, "experimental") and hasattr(keras.optimizers.experimental, "AdamW"):
            return keras.optimizers.experimental.AdamW(
                learning_rate=learning_rate,
                weight_decay=weight_decay,
            )
        print("WARNING: AdamW not available; falling back to Adam without optimizer weight decay.")
    return keras.optimizers.Adam(learning_rate=learning_rate)


def build_model(
    num_classes,
    learning_rate,
    freeze_base=True,
    unfreeze_top_n=0,
    dropout_1=DROPOUT_1,
    dropout_2=DROPOUT_2,
    weight_decay=WEIGHT_DECAY,
):
    """
    Build EfficientNetB0 model.
    freeze_base=True  : freeze entire base
    unfreeze_top_n>0  : unfreeze last N layers of base
    freeze_base=False : unfreeze full base
    """
    base = EfficientNetB0(
        include_top=False,
        weights="imagenet",
        input_shape=(*IMAGE_SIZE, 3),
    )

    # Freeze strategy
    if freeze_base:
        base.trainable = False
    elif unfreeze_top_n > 0:
        for layer in base.layers[:-unfreeze_top_n]:
            layer.trainable = False
        for layer in base.layers[-unfreeze_top_n:]:
            layer.trainable = True
    else:
        base.trainable = True

    # Classification head (v4: moderate dropout + L2)
    inputs = keras.Input(shape=(*IMAGE_SIZE, 3))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout_1)(x)
    x = layers.Dense(
        256, activation="relu",
        kernel_regularizer=keras.regularizers.l2(DENSE_L2)
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout_2)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer=make_optimizer(learning_rate, weight_decay),
        loss="categorical_crossentropy",
        metrics=["accuracy",
                 keras.metrics.Precision(name="precision"),
                 keras.metrics.Recall(name="recall")],
    )
    return model, base


model, base_model = build_model(NUM_CLASSES, PHASE1_LR, freeze_base=True)

trainable = sum([tf.size(v).numpy() for v in model.trainable_variables])
total = model.count_params()
print(f"Total params     : {total:,}")
print(f"Trainable params : {trainable:,}  (head only, base frozen)")
print(f"Dropout          : {DROPOUT_1:.2f} / {DROPOUT_2:.2f}")
print(f"Weight decay     : {WEIGHT_DECAY:g}")
model.summary()
# Out:
# Total params     : 4,385,964
# Trainable params : 333,321  (head only, base frozen)
# Dropout          : 0.40 / 0.30
# Weight decay     : 0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9)              │         2,313 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,385,964 (16.73 MB)
#  Trainable params: 333,321 (1.27 MB)
#  Non-trainable params: 4,052,643 (15.46 MB)

# %% [markdown]
# ## 🔧 10. Shared Callbacks Helper

# %%
def checkpoint_path(phase: int):
    return f"{MODEL_DIR}/best_phase{phase}_{RUN_VERSION}.keras"


def get_callbacks(phase: int, patience_es=15, patience_lr=6):
    """Return callbacks for a given training phase."""
    return [
        EarlyStopping(
            monitor="val_accuracy", patience=patience_es,
            restore_best_weights=True, verbose=1
        ),
        ModelCheckpoint(
            checkpoint_path(phase),
            monitor="val_accuracy", save_best_only=True, verbose=1
        ),
        ReduceLROnPlateau(
            monitor="val_loss", factor=0.3,
            patience=patience_lr, min_lr=1e-8, verbose=1
        ),
    ]

print("Callbacks ready")
# Out:
# Callbacks ready

# %% [markdown]
# ## 🏋️ 11. Phase 1 — Train Head Only (Base Frozen)
#
# The EfficientNetB0 backbone is completely frozen. Only the classification head learns.
# This establishes a good starting point before we touch the pretrained weights.

# %%
print("=" * 50)
print("  PHASE 1: Head only | Base frozen")
print(f"  Epochs: {PHASE1_EPOCHS} | LR: {PHASE1_LR}")
print("=" * 50)

history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=PHASE1_EPOCHS,
    callbacks=get_callbacks(phase=1),
    class_weight=class_weight_dict,
    verbose=1,
)

best_p1 = max(history1.history["val_accuracy"])
print(f"\nBest val accuracy (Phase 1): {best_p1:.4f}  ({best_p1*100:.2f}%)")
# Out:
# ==================================================
#   PHASE 1: Head only | Base frozen
#   Epochs: 20 | LR: 0.001
# ==================================================
# Epoch 1/20
#     130/Unknown 101s 662ms/step - accuracy: 0.6372 - loss: 1.1580 - precision: 0.6905 - recall: 0.5890
# Epoch 1: val_accuracy improved from None to 0.86230, saving model to output/models/best_phase1_v4.keras
#
# Epoch 1: finished saving model to output/models/best_phase1_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 123s 830ms/step - accuracy: 0.7454 - loss: 0.7765 - precision: 0.7782 - recall: 0.7135 - val_accuracy: 0.8623 - val_loss: 0.4849 - val_precision: 0.8976 - val_recall: 0.7720 - learning_rate: 0.0010
# Epoch 2/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.8676 - loss: 0.4152 - precision: 0.8769 - recall: 0.8544
# Epoch 2: val_accuracy improved from 0.86230 to 0.86795, saving model to output/models/best_phase1_v4.keras
#
# Epoch 2: finished saving model to output/models/best_phase1_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 61s 467ms/step - accuracy: 0.8712 - loss: 0.4086 - precision: 0.8820 - recall: 0.8611 - val_accuracy: 0.8679 - val_loss: 0.3537 - val_precision: 0.8782 - val_recall: 0.8465 - learning_rate: 0.0010
# Epoch 3/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.8889 - loss: 0.3249 - precision: 0.8950 - recall: 0.8782
# Epoch 3: val_accuracy improved from 0.86795 to 0.88488, saving model to output/models/best_phase1_v4.keras
#
# Epoch 3: finished saving model to output/models/best_phase1_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 60s 464ms/step - accuracy: 0.8979 - loss: 0.3183 - precision: 0.9026 - recall: 0.8882 - val_accuracy: 0.8849 - val_loss: 0.3463 - val_precision: 0.8912 - val_recall: 0.8781 - learning_rate: 0.0010
# Epoch 4/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.8918 - loss: 0.3350 - precision: 0.9004 - recall: 0.8876
# Epoch 4: val_accuracy improved from 0.88488 to 0.90068, saving model to output/models/best_phase1_v4.keras
#
# Epoch 4: finished saving model to output/models/best_phase1_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 60s 464ms/step - accuracy: 0.8993 - loss: 0.3218 - precision: 0.9064 - recall: 0.8955 - val_accuracy: 0.9007 - val_loss: 0.2805 - val_precision: 0.9025 - val_recall: 0.8984 - learning_rate: 0.0010
# Epoch 5/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.9102 - loss: 0.2961 - precision: 0.9170 - recall: 0.9070
# Epoch 5: val_accuracy improved from 0.90068 to 0.90745, saving model to output/models/best_phase1_v4.keras
#
# Epoch 5: finished saving model to output/models/best_phase1_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 61s 466ms/step - accuracy: 0.9124 - loss: 0.2977 - precision: 0.9183 - recall: 0.9088 - val_accuracy: 0.9074 - val_loss: 0.2818 - val_precision: 0.9072 - val_recall: 0.9052 - learning_rate: 0.0010
# Epoch 6/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.9110 - loss: 0.2854 - precision: 0.9172 - recall: 0.9070
# Epoch 6: val_accuracy improved from 0.90745 to 0.91535, saving model to output/models/best_phase1_v4.keras
#
# Epoch 6: finished saving model to output/models/best_phase1_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 61s 466ms/step - accuracy: 0.9143 - loss: 0.2822 - precision: 0.9194 - recall: 0.9083 - val_accuracy: 0.9153 - val_loss: 0.2882 - val_precision: 0.9184 - val_recall: 0.9142 - learning_rate: 0.0010
# Epoch 7/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.9231 - loss: 0.2419 - precision: 0.9277 - recall: 0.9207
# Epoch 7: val_accuracy did not improve from 0.91535
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 60s 459ms/step - accuracy: 0.9276 - loss: 0.2447 - precision: 0.9324 - recall: 0.9247 - val_accuracy: 0.9142 - val_loss: 0.2699 - val_precision: 0.9151 - val_recall: 0.9120 - learning_rate: 0.0010
# Epoch 8/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.9410 - loss: 0.2275 - precision: 0.9451 - recall: 0.9394
# Epoch 8: val_accuracy improved from 0.91535 to 0.93905, saving model to output/models/best_phase1_v4.keras
#
# Epoch 8: finished saving model to output/models/best_phase1_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 65s 500ms/step - accuracy: 0.9356 - loss: 0.2312 - precision: 0.9394 - recall: 0.9339 - val_accuracy: 0.9391 - val_loss: 0.2234 - val_precision: 0.9418 - val_recall: 0.9323 - learning_rate: 0.0010
# Epoch 9/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.9189 - loss: 0.2638 - precision: 0.9205 - recall: 0.9160
# Epoch 9: val_accuracy did not improve from 0.93905
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 65s 502ms/step - accuracy: 0.9267 - loss: 0.2497 - precision: 0.9282 - recall: 0.9235 - val_accuracy: 0.9176 - val_loss: 0.2863 - val_precision: 0.9175 - val_recall: 0.9165 - learning_rate: 0.0010
# Epoch 10/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9228 - loss: 0.2604 - precision: 0.9268 - recall: 0.9171
# Epoch 10: val_accuracy did not improve from 0.93905
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 61s 465ms/step - accuracy: 0.9284 - loss: 0.2600 - precision: 0.9321 - recall: 0.9230 - val_accuracy: 0.9120 - val_loss: 0.2868 - val_precision: 0.9119 - val_recall: 0.9108 - learning_rate: 0.0010
# Epoch 11/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.9184 - loss: 0.2752 - precision: 0.9212 - recall: 0.9163
# Epoch 11: val_accuracy did not improve from 0.93905
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 64s 489ms/step - accuracy: 0.9250 - loss: 0.2605 - precision: 0.9277 - recall: 0.9228 - val_accuracy: 0.9233 - val_loss: 0.2582 - val_precision: 0.9243 - val_recall: 0.9233 - learning_rate: 0.0010
# Epoch 12/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.9308 - loss: 0.2464 - precision: 0.9335 - recall: 0.9260
# Epoch 12: val_accuracy did not improve from 0.93905
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 69s 531ms/step - accuracy: 0.9332 - loss: 0.2356 - precision: 0.9357 - recall: 0.9298 - val_accuracy: 0.9187 - val_loss: 0.2491 - val_precision: 0.9208 - val_recall: 0.9187 - learning_rate: 0.0010
# Epoch 13/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9339 - loss: 0.2292 - precision: 0.9380 - recall: 0.9322
# Epoch 13: val_accuracy did not improve from 0.93905
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 63s 485ms/step - accuracy: 0.9368 - loss: 0.2318 - precision: 0.9404 - recall: 0.9349 - val_accuracy: 0.9176 - val_loss: 0.2739 - val_precision: 0.9186 - val_recall: 0.9176 - learning_rate: 0.0010
# Epoch 14/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.9266 - loss: 0.2421 - precision: 0.9270 - recall: 0.9227
# Epoch 14: val_accuracy did not improve from 0.93905
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 65s 495ms/step - accuracy: 0.9276 - loss: 0.2436 - precision: 0.9290 - recall: 0.9242 - val_accuracy: 0.9289 - val_loss: 0.2714 - val_precision: 0.9298 - val_recall: 0.9266 - learning_rate: 0.0010
# Epoch 15/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9354 - loss: 0.2277 - precision: 0.9362 - recall: 0.9337
# Epoch 15: val_accuracy did not improve from 0.93905
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 63s 485ms/step - accuracy: 0.9485 - loss: 0.2029 - precision: 0.9497 - recall: 0.9463 - val_accuracy: 0.9391 - val_loss: 0.2293 - val_precision: 0.9400 - val_recall: 0.9379 - learning_rate: 3.0000e-04
# Epoch 16/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.9560 - loss: 0.1790 - precision: 0.9566 - recall: 0.9542
# Epoch 16: val_accuracy improved from 0.93905 to 0.94131, saving model to output/models/best_phase1_v4.keras
#
# Epoch 16: finished saving model to output/models/best_phase1_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 65s 496ms/step - accuracy: 0.9533 - loss: 0.1880 - precision: 0.9546 - recall: 0.9518 - val_accuracy: 0.9413 - val_loss: 0.2178 - val_precision: 0.9423 - val_recall: 0.9402 - learning_rate: 3.0000e-04
# Epoch 17/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9456 - loss: 0.2045 - precision: 0.9478 - recall: 0.9418
# Epoch 17: val_accuracy did not improve from 0.94131
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 64s 488ms/step - accuracy: 0.9436 - loss: 0.2137 - precision: 0.9460 - recall: 0.9419 - val_accuracy: 0.9391 - val_loss: 0.2121 - val_precision: 0.9390 - val_recall: 0.9379 - learning_rate: 3.0000e-04
# Epoch 18/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.9452 - loss: 0.2057 - precision: 0.9490 - recall: 0.9435
# Epoch 18: val_accuracy improved from 0.94131 to 0.94808, saving model to output/models/best_phase1_v4.keras
#
# Epoch 18: finished saving model to output/models/best_phase1_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 61s 465ms/step - accuracy: 0.9477 - loss: 0.2030 - precision: 0.9504 - recall: 0.9455 - val_accuracy: 0.9481 - val_loss: 0.2003 - val_precision: 0.9481 - val_recall: 0.9481 - learning_rate: 3.0000e-04
# Epoch 19/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.9461 - loss: 0.1987 - precision: 0.9473 - recall: 0.9434
# Epoch 19: val_accuracy did not improve from 0.94808
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 60s 460ms/step - accuracy: 0.9485 - loss: 0.1939 - precision: 0.9502 - recall: 0.9460 - val_accuracy: 0.9379 - val_loss: 0.2155 - val_precision: 0.9390 - val_recall: 0.9379 - learning_rate: 3.0000e-04
# Epoch 20/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.9449 - loss: 0.2064 - precision: 0.9485 - recall: 0.9413
# Epoch 20: val_accuracy did not improve from 0.94808
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 62s 477ms/step - accuracy: 0.9501 - loss: 0.1926 - precision: 0.9526 - recall: 0.9480 - val_accuracy: 0.9345 - val_loss: 0.2156 - val_precision: 0.9356 - val_recall: 0.9345 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 18.
#
# Best val accuracy (Phase 1): 0.9481  (94.81%)

# %% [markdown]
# ## 🔓 12. Phase 2 — Partial Unfreeze (Top 20 Layers)
#
# **KEY FIX from v1**: Instead of unfreezing the entire network at once, we only unfreeze the last 20 layers of EfficientNetB0. This is much gentler and prevents the wild validation swings seen in v1.
#
# Learning rate is reduced to `1e-5` (was `1e-4` in v1).

# %%
# Rebuild model with top 20 layers unfrozen
model, base_model = build_model(
    NUM_CLASSES, PHASE2_LR,
    freeze_base=False, unfreeze_top_n=20
)

# Load best weights from Phase 1
model.load_weights(checkpoint_path(1))

trainable = sum([tf.size(v).numpy() for v in model.trainable_variables])
print(f"Trainable params now: {trainable:,}  (head + top 20 base layers)")
print()
print("=" * 50)
print("  PHASE 2: Partial unfreeze (top 20 layers)")
print(f"  Epochs: {PHASE2_EPOCHS} | LR: {PHASE2_LR}")
print("=" * 50)

history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=PHASE2_EPOCHS,
    callbacks=get_callbacks(phase=2, patience_es=12, patience_lr=5),
    class_weight=class_weight_dict,
    verbose=1,
)

best_p2 = max(history2.history["val_accuracy"])
print(f"\nBest val accuracy (Phase 2): {best_p2:.4f}  ({best_p2*100:.2f}%)")
# Out:
# Trainable params now: 1,684,281  (head + top 20 base layers)
#
# ==================================================
#   PHASE 2: Partial unfreeze (top 20 layers)
#   Epochs: 25 | LR: 1e-05
# ==================================================
# Epoch 1/25
#     130/Unknown 72s 451ms/step - accuracy: 0.8229 - loss: 0.6151 - precision: 0.8432 - recall: 0.8037
# Epoch 1: val_accuracy improved from None to 0.92325, saving model to output/models/best_phase2_v4.keras
#
# Epoch 1: finished saving model to output/models/best_phase2_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 86s 560ms/step - accuracy: 0.8345 - loss: 0.5668 - precision: 0.8524 - recall: 0.8146 - val_accuracy: 0.9233 - val_loss: 0.2570 - val_precision: 0.9253 - val_recall: 0.9233 - learning_rate: 1.0000e-05
# Epoch 2/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.8348 - loss: 0.5630 - precision: 0.8548 - recall: 0.8203
# Epoch 2: val_accuracy improved from 0.92325 to 0.92551, saving model to output/models/best_phase2_v4.keras
#
# Epoch 2: finished saving model to output/models/best_phase2_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 75s 574ms/step - accuracy: 0.8555 - loss: 0.4746 - precision: 0.8713 - recall: 0.8424 - val_accuracy: 0.9255 - val_loss: 0.2759 - val_precision: 0.9264 - val_recall: 0.9233 - learning_rate: 1.0000e-05
# Epoch 3/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.8691 - loss: 0.4245 - precision: 0.8806 - recall: 0.8536
# Epoch 3: val_accuracy did not improve from 0.92551
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 70s 537ms/step - accuracy: 0.8727 - loss: 0.4062 - precision: 0.8836 - recall: 0.8582 - val_accuracy: 0.9176 - val_loss: 0.2848 - val_precision: 0.9218 - val_recall: 0.9176 - learning_rate: 1.0000e-05
# Epoch 4/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.8845 - loss: 0.3959 - precision: 0.8989 - recall: 0.8730
# Epoch 4: val_accuracy did not improve from 0.92551
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 69s 531ms/step - accuracy: 0.8911 - loss: 0.3650 - precision: 0.9028 - recall: 0.8814 - val_accuracy: 0.9199 - val_loss: 0.2789 - val_precision: 0.9217 - val_recall: 0.9165 - learning_rate: 1.0000e-05
# Epoch 5/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.8943 - loss: 0.3611 - precision: 0.9031 - recall: 0.8810
# Epoch 5: val_accuracy did not improve from 0.92551
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 78s 601ms/step - accuracy: 0.8947 - loss: 0.3520 - precision: 0.9043 - recall: 0.8831 - val_accuracy: 0.9221 - val_loss: 0.2708 - val_precision: 0.9242 - val_recall: 0.9221 - learning_rate: 1.0000e-05
# Epoch 6/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9082 - loss: 0.3322 - precision: 0.9141 - recall: 0.8988
# Epoch 6: val_accuracy did not improve from 0.92551
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 78s 595ms/step - accuracy: 0.9063 - loss: 0.3205 - precision: 0.9121 - recall: 0.8964 - val_accuracy: 0.9255 - val_loss: 0.2624 - val_precision: 0.9253 - val_recall: 0.9233 - learning_rate: 1.0000e-05
# Epoch 7/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.8975 - loss: 0.3419 - precision: 0.9065 - recall: 0.8877
# Epoch 7: val_accuracy improved from 0.92551 to 0.92777, saving model to output/models/best_phase2_v4.keras
#
# Epoch 7: finished saving model to output/models/best_phase2_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 75s 574ms/step - accuracy: 0.9039 - loss: 0.3237 - precision: 0.9121 - recall: 0.8935 - val_accuracy: 0.9278 - val_loss: 0.2559 - val_precision: 0.9275 - val_recall: 0.9244 - learning_rate: 3.0000e-06
# Epoch 8/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.9005 - loss: 0.3460 - precision: 0.9074 - recall: 0.8955
# Epoch 8: val_accuracy improved from 0.92777 to 0.92889, saving model to output/models/best_phase2_v4.keras
#
# Epoch 8: finished saving model to output/models/best_phase2_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 73s 562ms/step - accuracy: 0.9025 - loss: 0.3327 - precision: 0.9089 - recall: 0.8959 - val_accuracy: 0.9289 - val_loss: 0.2567 - val_precision: 0.9287 - val_recall: 0.9266 - learning_rate: 3.0000e-06
# Epoch 9/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.9185 - loss: 0.2676 - precision: 0.9272 - recall: 0.9127
# Epoch 9: val_accuracy did not improve from 0.92889
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 79s 544ms/step - accuracy: 0.9131 - loss: 0.2982 - precision: 0.9210 - recall: 0.9056 - val_accuracy: 0.9266 - val_loss: 0.2539 - val_precision: 0.9266 - val_recall: 0.9255 - learning_rate: 3.0000e-06
# Epoch 10/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.9159 - loss: 0.2996 - precision: 0.9234 - recall: 0.9109
# Epoch 10: val_accuracy did not improve from 0.92889
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 71s 544ms/step - accuracy: 0.9138 - loss: 0.3020 - precision: 0.9198 - recall: 0.9080 - val_accuracy: 0.9278 - val_loss: 0.2457 - val_precision: 0.9287 - val_recall: 0.9266 - learning_rate: 3.0000e-06
# Epoch 11/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.9202 - loss: 0.2804 - precision: 0.9291 - recall: 0.9151
# Epoch 11: val_accuracy did not improve from 0.92889
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 72s 554ms/step - accuracy: 0.9124 - loss: 0.2921 - precision: 0.9199 - recall: 0.9056 - val_accuracy: 0.9289 - val_loss: 0.2465 - val_precision: 0.9288 - val_recall: 0.9278 - learning_rate: 3.0000e-06
# Epoch 12/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.9163 - loss: 0.2904 - precision: 0.9252 - recall: 0.9088
# Epoch 12: val_accuracy did not improve from 0.92889
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 70s 540ms/step - accuracy: 0.9175 - loss: 0.2791 - precision: 0.9250 - recall: 0.9102 - val_accuracy: 0.9289 - val_loss: 0.2468 - val_precision: 0.9288 - val_recall: 0.9278 - learning_rate: 3.0000e-06
# Epoch 13/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9078 - loss: 0.3238 - precision: 0.9182 - recall: 0.8994
# Epoch 13: val_accuracy improved from 0.92889 to 0.93002, saving model to output/models/best_phase2_v4.keras
#
# Epoch 13: finished saving model to output/models/best_phase2_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 71s 544ms/step - accuracy: 0.9044 - loss: 0.3257 - precision: 0.9149 - recall: 0.8976 - val_accuracy: 0.9300 - val_loss: 0.2389 - val_precision: 0.9310 - val_recall: 0.9289 - learning_rate: 3.0000e-06
# Epoch 14/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9105 - loss: 0.3312 - precision: 0.9146 - recall: 0.9017
# Epoch 14: val_accuracy improved from 0.93002 to 0.93228, saving model to output/models/best_phase2_v4.keras
#
# Epoch 14: finished saving model to output/models/best_phase2_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 70s 541ms/step - accuracy: 0.9155 - loss: 0.3054 - precision: 0.9203 - recall: 0.9078 - val_accuracy: 0.9323 - val_loss: 0.2394 - val_precision: 0.9332 - val_recall: 0.9300 - learning_rate: 3.0000e-06
# Epoch 15/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9223 - loss: 0.3010 - precision: 0.9308 - recall: 0.9179
# Epoch 15: val_accuracy improved from 0.93228 to 0.93341, saving model to output/models/best_phase2_v4.keras
#
# Epoch 15: finished saving model to output/models/best_phase2_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 70s 540ms/step - accuracy: 0.9252 - loss: 0.2786 - precision: 0.9323 - recall: 0.9197 - val_accuracy: 0.9334 - val_loss: 0.2360 - val_precision: 0.9333 - val_recall: 0.9323 - learning_rate: 3.0000e-06
# Epoch 16/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.9246 - loss: 0.2662 - precision: 0.9311 - recall: 0.9177
# Epoch 16: val_accuracy did not improve from 0.93341
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 71s 542ms/step - accuracy: 0.9172 - loss: 0.2883 - precision: 0.9237 - recall: 0.9109 - val_accuracy: 0.9312 - val_loss: 0.2355 - val_precision: 0.9321 - val_recall: 0.9300 - learning_rate: 3.0000e-06
# Epoch 17/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.9271 - loss: 0.2580 - precision: 0.9343 - recall: 0.9213
# Epoch 17: val_accuracy did not improve from 0.93341
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 74s 565ms/step - accuracy: 0.9269 - loss: 0.2689 - precision: 0.9323 - recall: 0.9199 - val_accuracy: 0.9312 - val_loss: 0.2347 - val_precision: 0.9312 - val_recall: 0.9312 - learning_rate: 3.0000e-06
# Epoch 18/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9097 - loss: 0.2978 - precision: 0.9200 - recall: 0.9034
# Epoch 18: val_accuracy did not improve from 0.93341
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 71s 545ms/step - accuracy: 0.9163 - loss: 0.2878 - precision: 0.9257 - recall: 0.9112 - val_accuracy: 0.9289 - val_loss: 0.2368 - val_precision: 0.9289 - val_recall: 0.9289 - learning_rate: 3.0000e-06
# Epoch 19/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9293 - loss: 0.2628 - precision: 0.9333 - recall: 0.9236
# Epoch 19: val_accuracy did not improve from 0.93341
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 70s 540ms/step - accuracy: 0.9252 - loss: 0.2602 - precision: 0.9299 - recall: 0.9184 - val_accuracy: 0.9289 - val_loss: 0.2346 - val_precision: 0.9289 - val_recall: 0.9289 - learning_rate: 3.0000e-06
# Epoch 20/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9317 - loss: 0.2606 - precision: 0.9367 - recall: 0.9273
# Epoch 20: val_accuracy improved from 0.93341 to 0.93454, saving model to output/models/best_phase2_v4.keras
#
# Epoch 20: finished saving model to output/models/best_phase2_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 71s 543ms/step - accuracy: 0.9281 - loss: 0.2699 - precision: 0.9330 - recall: 0.9230 - val_accuracy: 0.9345 - val_loss: 0.2306 - val_precision: 0.9345 - val_recall: 0.9345 - learning_rate: 3.0000e-06
# Epoch 21/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9305 - loss: 0.2556 - precision: 0.9375 - recall: 0.9233
# Epoch 21: val_accuracy did not improve from 0.93454
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 71s 545ms/step - accuracy: 0.9298 - loss: 0.2565 - precision: 0.9355 - recall: 0.9228 - val_accuracy: 0.9312 - val_loss: 0.2286 - val_precision: 0.9332 - val_recall: 0.9300 - learning_rate: 3.0000e-06
# Epoch 22/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9271 - loss: 0.2662 - precision: 0.9349 - recall: 0.9221
# Epoch 22: val_accuracy did not improve from 0.93454
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 72s 554ms/step - accuracy: 0.9209 - loss: 0.2831 - precision: 0.9259 - recall: 0.9158 - val_accuracy: 0.9323 - val_loss: 0.2295 - val_precision: 0.9333 - val_recall: 0.9323 - learning_rate: 3.0000e-06
# Epoch 23/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9224 - loss: 0.2667 - precision: 0.9307 - recall: 0.9174
# Epoch 23: val_accuracy improved from 0.93454 to 0.93905, saving model to output/models/best_phase2_v4.keras
#
# Epoch 23: finished saving model to output/models/best_phase2_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 72s 552ms/step - accuracy: 0.9259 - loss: 0.2645 - precision: 0.9321 - recall: 0.9201 - val_accuracy: 0.9391 - val_loss: 0.2233 - val_precision: 0.9400 - val_recall: 0.9368 - learning_rate: 3.0000e-06
# Epoch 24/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.9286 - loss: 0.2459 - precision: 0.9350 - recall: 0.9220
# Epoch 24: val_accuracy did not improve from 0.93905
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 73s 564ms/step - accuracy: 0.9325 - loss: 0.2460 - precision: 0.9383 - recall: 0.9274 - val_accuracy: 0.9368 - val_loss: 0.2225 - val_precision: 0.9377 - val_recall: 0.9345 - learning_rate: 3.0000e-06
# Epoch 25/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.9332 - loss: 0.2400 - precision: 0.9384 - recall: 0.9297
# Epoch 25: val_accuracy improved from 0.93905 to 0.94018, saving model to output/models/best_phase2_v4.keras
#
# Epoch 25: finished saving model to output/models/best_phase2_v4.keras
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 76s 583ms/step - accuracy: 0.9276 - loss: 0.2543 - precision: 0.9324 - recall: 0.9245 - val_accuracy: 0.9402 - val_loss: 0.2213 - val_precision: 0.9401 - val_recall: 0.9391 - learning_rate: 3.0000e-06
# Restoring model weights from the end of the best epoch: 25.
#
# Best val accuracy (Phase 2): 0.9402  (94.02%)

# %% [markdown]
# ## 📈 14. Training Curves — All 3 Phases

# %%
def merge_histories(*histories):
    merged = {}
    for h in histories:
        for key, vals in h.history.items():
            merged.setdefault(key, []).extend(vals)
    return merged

history = merge_histories(history1, history2)
p1_end  = len(history1.history["accuracy"])

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

for ax, (train_key, val_key), title in zip(
    axes,
    [("accuracy", "val_accuracy"), ("loss", "val_loss")],
    ["Accuracy", "Loss"]
):
    epochs = range(1, len(history[train_key]) + 1)
    ax.plot(epochs, history[train_key], label=f"Train {title}", linewidth=2, color="#3498db")
    ax.plot(epochs, history[val_key],   label=f"Val {title}",   linewidth=2, linestyle="--", color="#e67e22")
    ax.axvline(x=p1_end, color="#95a5a6", linestyle=":", linewidth=1.5)
    
    ymin, ymax = ax.get_ylim()
    ax.text(p1_end / 2, ymax * 0.97, "Phase 1", ha="center", fontsize=9, color="#7f8c8d")
    ax.text((p1_end + len(epochs)) / 2, ymax * 0.97, "Phase 2", ha="center", fontsize=9, color="#7f8c8d")
    
    ax.set_title(f"{title} over Epochs (2-Phase Training)", fontsize=13, fontweight="bold")
    ax.set_xlabel("Epoch")
    ax.set_ylabel(title)
    ax.legend()
    ax.grid(True, linestyle="--", alpha=0.4)

plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/plots/training_curves_final.png", dpi=150, bbox_inches="tight")
plt.show()
print("Saved -> output/plots/training_curves_final.png")
# Out:
# Saved -> output/plots/training_curves_final.png

# %% [markdown]
# ## 🎯 15. Evaluation on Test Set

# %%
best_model = keras.models.load_model(f"{MODEL_DIR}/best_phase2.keras")

y_pred_probs = best_model.predict(test_ds, verbose=0)
y_pred       = np.argmax(y_pred_probs, axis=1)
y_true       = y_test

test_loss, test_acc, test_prec, test_rec = best_model.evaluate(test_ds, verbose=0)
f1 = f1_score(y_true, y_pred, average="macro")

print(f"{'='*48}")
print(f"  FINAL TEST RESULTS (Phase 2 Model)")
print(f"{'='*48}")
print(f"  Accuracy  : {test_acc:.4f}  ({test_acc*100:.2f}%)")
print(f"  Precision : {test_prec:.4f}")
print(f"  Recall    : {test_rec:.4f}")
print(f"  F1-Score  : {f1:.4f}  (macro)")
print(f"{'='*48}")
# Out:
# ================================================
#   FINAL TEST RESULTS (Phase 2 Model)
# ================================================
#   Accuracy  : 0.2280  (22.80%)
#   Precision : 0.2271
#   Recall    : 0.2043
#   F1-Score  : 0.1546  (macro)
# ================================================

# %% [markdown]
# ## 📋 16. Per-Class Classification Report

# %%
target_names = le.classes_
report = classification_report(y_true, y_pred, target_names=target_names)
print(report)
with open(f"{OUTPUT_DIR}/classification_report_v4.txt", "w") as f:
    f.write(report)
print("Saved -> output/classification_report_v4.txt")
# Out:
#               precision    recall  f1-score   support
#
#      apple_A       0.27      0.06      0.10       109
#      apple_B       0.29      0.65      0.40       100
#      apple_C       0.23      0.15      0.18       103
#     banana_A       0.18      0.42      0.25        84
#     banana_B       0.32      0.45      0.38       165
#     banana_C       0.00      0.00      0.00        47
#     orange_A       0.09      0.01      0.02        84
#     orange_B       0.15      0.01      0.02       176
#     orange_C       0.02      0.11      0.04        18
#
#     accuracy                           0.23       886
#    macro avg       0.17      0.21      0.15       886
# weighted avg       0.21      0.23      0.18       886
#
# Saved -> output/classification_report_v4.txt

# %% [markdown]
# ## 🔢 17. Confusion Matrix

# %%
cm      = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

fig, axes = plt.subplots(1, 2, figsize=(18, 7))
for ax, data, fmt, title in zip(
    axes,
    [cm, cm_norm],
    ["d", ".2f"],
    ["Confusion Matrix (Counts)", "Confusion Matrix (Normalized)"]
):
    sns.heatmap(
        data, annot=True, fmt=fmt, cmap="Blues",
        xticklabels=target_names, yticklabels=target_names,
        ax=ax, linewidths=0.5, linecolor="white",
        annot_kws={"size": 9},
    )
    ax.set_title(title, fontsize=13, fontweight="bold")
    ax.set_xlabel("Predicted", fontsize=11)
    ax.set_ylabel("True", fontsize=11)
    ax.tick_params(axis="x", rotation=35)
    ax.tick_params(axis="y", rotation=0)

plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/plots/confusion_matrix_v4.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 🍎🍊🍌 18. Per-Fruit Per-Grade Accuracy Heatmap

# %%
results = []
for class_name in sorted(CLASS_NAMES):
    class_idx    = le.transform([class_name])[0]
    mask         = (y_true == class_idx)
    if mask.sum() == 0:
        continue
    correct      = (y_pred[mask] == class_idx).sum()
    total        = mask.sum()
    fruit, grade = class_name.split("_")
    results.append({
        "Class":    class_name,
        "Fruit":    fruit.capitalize(),
        "Grade":    grade,
        "Correct":  correct,
        "Total":    total,
        "Accuracy": correct / total,
    })

df_results = pd.DataFrame(results)
print(f"{'Class':<14} {'Correct':>8} {'Total':>8} {'Accuracy':>10}")
print("-" * 44)
for _, row in df_results.iterrows():
    bar = chr(9608) * int(row["Accuracy"] * 20)
    print(f"{row['Class']:<14} {int(row['Correct']):>8} {int(row['Total']):>8}  {row['Accuracy']:>8.1%}  {bar}")

pivot = df_results.pivot(index="Fruit", columns="Grade", values="Accuracy")
fig, ax = plt.subplots(figsize=(6, 4))
sns.heatmap(pivot, annot=True, fmt=".1%", cmap="RdYlGn",
            vmin=0.5, vmax=1.0, ax=ax, linewidths=0.5,
            annot_kws={"size": 13, "fontweight": "bold"})
ax.set_title("Per-Fruit Per-Grade Accuracy (v4)", fontsize=13, fontweight="bold")
ax.set_xlabel("Grade")
ax.set_ylabel("")
plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/plots/per_class_accuracy_v4.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# Class           Correct    Total   Accuracy
# --------------------------------------------
# apple_A               7      109      6.4%  █
# apple_B              65      100     65.0%  █████████████
# apple_C              15      103     14.6%  ██
# banana_A             35       84     41.7%  ████████
# banana_B             75      165     45.5%  █████████
# banana_C              0       47      0.0%
# orange_A              1       84      1.2%
# orange_B              2      176      1.1%
# orange_C              2       18     11.1%  ██

# %% [markdown]
# ## 🔥 19. Grad-CAM Visualizations
#
# Shows which region of the fruit the model focuses on for grading.

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name):
    grad_model = Model(
        inputs=model.inputs,
        outputs=[model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        pred_index   = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]
    grads       = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    heatmap      = conv_outputs[0] @ pooled_grads[..., tf.newaxis]
    heatmap      = tf.squeeze(heatmap)
    heatmap      = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy(), predictions.numpy()


def overlay_gradcam(img_path, heatmap, alpha=0.4):
    img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMAGE_SIZE)
    hm  = cv2.applyColorMap(np.uint8(255 * cv2.resize(heatmap, IMAGE_SIZE)), cv2.COLORMAP_JET)
    hm  = cv2.cvtColor(hm, cv2.COLOR_BGR2RGB)
    return img, (img * (1 - alpha) + hm * alpha).astype(np.uint8)


# Find last conv layer
last_conv = None
for layer in best_model.layers:
    if isinstance(layer, keras.Model):
        for sub in layer.layers:
            if isinstance(sub, layers.Conv2D):
                last_conv = sub.name
if last_conv is None:
    last_conv = "top_conv"
print(f"Using layer: {last_conv}")

# Plot 2 samples per class
N_SHOW = 2
fig, axes = plt.subplots(NUM_CLASSES, N_SHOW * 2, figsize=(4 * N_SHOW * 2, 3.5 * NUM_CLASSES))
grade_colors = {"A": "#2ecc71", "B": "#f39c12", "C": "#e74c3c"}

for row, class_name in enumerate(sorted(CLASS_NAMES)):
    class_idx = le.transform([class_name])[0]
    subset    = df_test[df_test["label"] == class_name]
    samples   = subset.sample(min(N_SHOW, len(subset)), random_state=RANDOM_STATE)
    _, grade  = class_name.split("_")

    for col_pair, (_, sample) in enumerate(samples.iterrows()):
        path = sample["image_path"]
        img_tensor = np.expand_dims(load_and_preprocess(path), axis=0)
        try:
            heatmap, preds = make_gradcam_heatmap(img_tensor, best_model, last_conv)
            pred_label     = le.inverse_transform([np.argmax(preds[0])])[0]
            original, overlay = overlay_gradcam(path, heatmap)

            axes[row, col_pair*2].imshow(original)
            axes[row, col_pair*2].axis("off")
            if col_pair == 0:
                axes[row, col_pair*2].set_ylabel(class_name, fontsize=9, fontweight="bold")

            correct = pred_label == class_name
            axes[row, col_pair*2+1].imshow(overlay)
            axes[row, col_pair*2+1].axis("off")
            axes[row, col_pair*2+1].set_title(
                f"Pred: {pred_label}",
                fontsize=8, fontweight="bold",
                color="#2ecc71" if correct else "#e74c3c"
            )
        except Exception:
            axes[row, col_pair*2].axis("off")
            axes[row, col_pair*2+1].axis("off")

plt.suptitle("Grad-CAM: Original vs Heatmap (green=correct, red=wrong)",
             fontsize=13, fontweight="bold")
plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/gradcam/gradcam_v4.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved -> output/gradcam/gradcam_v4.png")
# Out:
# Using layer: top_conv
# Saved -> output/gradcam/gradcam_v4.png

# %% [markdown]
# ## 🔮 20. Predict a Single Image

# %%
def predict_fruit_grade(image_path, model, label_encoder):
    img        = load_and_preprocess(image_path, augment=False)
    preds      = model.predict(np.expand_dims(img, 0), verbose=0)[0]
    pred_idx   = np.argmax(preds)
    pred_label = label_encoder.inverse_transform([pred_idx])[0]
    confidence = preds[pred_idx]
    fruit, grade = pred_label.split("_")

    grade_desc = {"A": "Premium", "B": "Average", "C": "Low"}
    print(f"Fruit      : {fruit.capitalize()}")
    print(f"Grade      : {grade} ({grade_desc[grade]} quality)")
    print(f"Confidence : {confidence:.2%}")
    print("\nTop 3:")
    for idx in np.argsort(preds)[::-1][:3]:
        print(f"  {label_encoder.inverse_transform([idx])[0]:<14} {preds[idx]:.2%}")

    img_disp = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(4, 4))
    plt.imshow(img_disp)
    plt.axis("off")
    plt.title(f"{fruit.capitalize()} — Grade {grade} ({confidence:.1%})",
              fontsize=12, fontweight="bold",
              color={"A": "#2ecc71", "B": "#f39c12", "C": "#e74c3c"}[grade])
    plt.show()

# Try on a random test image
sample_path = df_test.sample(1, random_state=42)["image_path"].values[0]
predict_fruit_grade(sample_path, best_model, le)
# Out:
# Fruit      : Orange
# Grade      : C (Low quality)
# Confidence : 100.00%
#
# Top 3:
#   orange_C       100.00%
#   banana_B       0.00%
#   banana_C       0.00%

# %% [markdown]
# ## 💾 21. Save Final Model

# %%
best_model.save(f"{MODEL_DIR}/fruit_grader_final.keras")
np.save(f"{MODEL_DIR}/class_names.npy", le.classes_)

print("=" * 55)
print("  STEP 2 COMPLETE (2-Phase Training Final)")
print("=" * 55)
print(f"  Test Accuracy : {test_acc:.4f}  ({test_acc*100:.2f}%)")
print(f"  F1-Score      : {f1:.4f}  (macro)")
print("")
print("  Strategy:")
print("    Phase 1: Train head, freeze base (20 epochs)")
print("    Phase 2: Unfreeze top 20 layers (25 epochs)")
print("    No Phase 3: Avoid overfitting to ~15-20% K-Means label noise")
print("")
print("  Output:")
print(f"    {MODEL_DIR}/fruit_grader_final.keras")
print(f"    {MODEL_DIR}/class_names.npy")
print(f"    {OUTPUT_DIR}/plots/training_curves_final.png")
print(f"    {OUTPUT_DIR}/plots/confusion_matrix_v2.png")
print(f"    {OUTPUT_DIR}/plots/per_class_accuracy_v2.png")
print(f"    {OUTPUT_DIR}/gradcam/gradcam_v2.png")
# Out:
# =======================================================
#   STEP 2 COMPLETE (2-Phase Training Final)
# =======================================================
#   Test Accuracy : 0.2280  (22.80%)
#   F1-Score      : 0.1546  (macro)
#
#   Strategy:
#     Phase 1: Train head, freeze base (20 epochs)
#     Phase 2: Unfreeze top 20 layers (25 epochs)
#     No Phase 3: Avoid overfitting to ~15-20% K-Means label noise
#
#   Output:
#     output/models/fruit_grader_final.keras
#     output/models/class_names.npy
#     output/plots/training_curves_final.png
#     output/plots/confusion_matrix_v2.png
#     output/plots/per_class_accuracy_v2.png
#     output/gradcam/gradcam_v2.png
